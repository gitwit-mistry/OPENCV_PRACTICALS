# %%
# importing dependencies
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## `Task 4.1`

# %% [markdown]
# ## 📌 Create image by yourself Using Python Code

# %%
image  = np.ones(shape=(300,300,3))

# %%
created_images = np.random.randint(0,255,(300,300,3))

# %%
plt.imshow(created_images)

# %%
created_rectange = cv2.rectangle(created_images,(50,50),(100,100),(250,250,0),10)

# %%
plt.imshow(created_images)

# %%
plt.imshow(cv2.rectangle(created_images,(200,50),(250,100),(250,250,0),10))

# %%
plt.imshow(cv2.ellipse(created_images,(150,220),(100, 25),0,0,360,(0,250,0),10))

# %%
np.array([[150,100],[100,150],[200,150]],np.int32)
# Out:
# array([[150, 100],
#        [100, 150],
#        [200, 150]])

# %%
plt.imshow(cv2.polylines(created_images,[np.array([[150,100],[100,150],[200,150]],np.int32)],True,(250,0,0),5))

# %%
plt.imshow(cv2.putText(created_images,"hello World!",(60,30),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,250,3)))

# %%
plt.imshow(created_images)

# %%
plt.imsave("created_image_face.png",created_images.astype('uint8'))

# %% [markdown]
# ## `Task 4.2`

# %% [markdown]
# ## 📌 Take 2 image crop some part of both image and swap it.

# %%
image1 = cv2.imread('riri.jpg')
image1 = cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
image2 = cv2.imread('JR.png')
image2 = cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
image1_crop = image1[10:250,100:350,:].copy()
plt.imshow(image1_crop)

# %%
offset = 100
image2_crop = image2[10+offset:250+offset,100+offset:350+offset,:].copy()
plt.imshow(image2_crop)

# %%
image1[10:250,100:350,:] = image2_crop

# %%
plt.imshow(image1)

# %%
offset = 100
image2[10+offset:250+offset,100+offset:350+offset,:] = image1_crop

# %%
plt.imshow(image2)

# %% [markdown]
# ## `Task 4.3`

# %% [markdown]
# ## 📌 Take 2 image and combine it to form single image. For example collage

# %%
plt.imshow(image1_crop)

# %%
plt.imshow(image2_crop)

# %%
combined_image = np.hstack([image1_crop,image2_crop])

# %%
plt.imshow(combined_image)

# %% [markdown]
# ### End of task 4!!
